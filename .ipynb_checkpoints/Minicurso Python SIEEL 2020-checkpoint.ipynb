# %% [markdown]
# # O que é Python
#
# Python é uma linguagem de programação:
# * de alto nível
# * interpretada
# * de script
# * imperativa
# * orientada a objetos
# * funcional
# * de tipagem dinâmica
# * forte
#
# ## Sintaxe

# %%
a=0

if a==0:
    pass
elif (a==1)and(a==1): # and, or, not
    pass
else:
    pass

while a!=2:
    a += 1

for i in range(a):
    print(i)

for i in ['Abacaxi', 'Banana', 'Maça']:
    print(i)
# Out:
# 0
# 1
# Abacaxi
# Banana
# Maça

# %% [markdown]
# ## Definição de funções

# %%
def func1(a, b=5):
    return a+b
print(func1(1, 4))
print(func1(1))
print(func1(1, b=8))
# Out:
# 5
# 6
# 9

# %% [markdown]
# ## Importar bibliotecas

# %%
import numpy as np # Funções matemáticas otimizadas
import pandas as pd # Operação de DataFrames
import matplotlib.pyplot as plt # Plot
import pandas_datareader as pdr # Importar dados
import datetime # Funções e definição de data e hora
import statsmodels.api as sm # Modelos estatisticos (ex. regressão)
#from pandas.core import datetools

# %% [markdown]
# ## Trabalhando com dados financeiros da Apple do Yahoo! Finance

# %%
aapl = pdr.get_data_yahoo('AAPL', start=datetime.datetime(2006, 10, 1), end=datetime.datetime(2012, 1, 1))
aapl
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2006-10-02  10.838572  10.614285  10.728572  10.694285  178159800   9.241351
# 2006-10-03  10.707143  10.455714  10.635715  10.582857  197677200   9.145061
# 2006-10-04  10.780000  10.451428  10.585714  10.768572  207270700   9.305547
# 2006-10-05  10.880000  10.590000  10.647142  10.690000  170970800   9.237648
# 2006-10-06  10.720000  10.544286  10.631429  10.602858  116739700   9.162347
# ...               ...        ...        ...        ...        ...        ...
# 2011-12-23  57.655716  57.070000  57.098572  57.618572   67349800  49.790466
# 2011-12-27  58.441429  57.574287  57.585712  58.075714   66269000  50.185513
# 2011-12-28  58.321430  57.334286  58.127144  57.520000   57165500  49.705292
# 2011-12-29  57.950001  57.215714  57.628571  57.874287   53994500  50.011452
# 2011-12-30  58.040001  57.641430  57.644287  57.857143   44915500  49.996635
#
# [1323 rows x 6 columns]

# %%
aapl.head()
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2006-10-02  10.838572  10.614285  10.728572  10.694285  178159800   9.241351
# 2006-10-03  10.707143  10.455714  10.635715  10.582857  197677200   9.145061
# 2006-10-04  10.780000  10.451428  10.585714  10.768572  207270700   9.305547
# 2006-10-05  10.880000  10.590000  10.647142  10.690000  170970800   9.237648
# 2006-10-06  10.720000  10.544286  10.631429  10.602858  116739700   9.162347

# %%
aapl.tail()
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2011-12-23  57.655716  57.070000  57.098572  57.618572  67349800  49.790466
# 2011-12-27  58.441429  57.574287  57.585712  58.075714  66269000  50.185513
# 2011-12-28  58.321430  57.334286  58.127144  57.520000  57165500  49.705292
# 2011-12-29  57.950001  57.215714  57.628571  57.874287  53994500  50.011452
# 2011-12-30  58.040001  57.641430  57.644287  57.857143  44915500  49.996635

# %%
aapl.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count  1323.000000  1323.000000  1323.000000  1323.000000  1.323000e+03
# mean     29.237566    28.507684    28.901012    28.889151  1.882896e+08
# std      14.199012    14.029758    14.123131    14.119734  1.027007e+08
# min      10.568571    10.371428    10.488571    10.461429  3.937360e+07
# 25%      17.752857    17.182143    17.457857    17.431429  1.122037e+08
# 50%      25.642857    24.725714    25.260000    25.120001  1.629866e+08
# 75%      39.132858    38.351429    38.777143    38.699999  2.316230e+08
# max      60.957142    59.427143    60.251427    60.320000  8.432424e+08
#
#          Adj Close
# count  1323.000000
# mean     24.964252
# std      12.201417
# min       9.040131
# 25%      15.063183
# 50%      21.707180
# 75%      33.442190
# max      52.124886

# %%
aapl.to_csv('aapl.csv')
df = pd.read_csv('aapl.csv', header=0, index_col='Date', parse_dates=True)
df
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2006-10-02  10.838572  10.614285  10.728572  10.694285  178159800   9.241351
# 2006-10-03  10.707143  10.455714  10.635715  10.582857  197677200   9.145061
# 2006-10-04  10.780000  10.451428  10.585714  10.768572  207270700   9.305547
# 2006-10-05  10.880000  10.590000  10.647142  10.690000  170970800   9.237648
# 2006-10-06  10.720000  10.544286  10.631429  10.602858  116739700   9.162347
# ...               ...        ...        ...        ...        ...        ...
# 2011-12-23  57.655716  57.070000  57.098572  57.618572   67349800  49.790466
# 2011-12-27  58.441429  57.574287  57.585712  58.075714   66269000  50.185513
# 2011-12-28  58.321430  57.334286  58.127144  57.520000   57165500  49.705292
# 2011-12-29  57.950001  57.215714  57.628571  57.874287   53994500  50.011452
# 2011-12-30  58.040001  57.641430  57.644287  57.857143   44915500  49.996635
#
# [1323 rows x 6 columns]

# %%
aapl.index
# Out:
# DatetimeIndex(['2006-10-02', '2006-10-03', '2006-10-04', '2006-10-05',
#                '2006-10-06', '2006-10-09', '2006-10-10', '2006-10-11',
#                '2006-10-12', '2006-10-13',
#                ...
#                '2011-12-16', '2011-12-19', '2011-12-20', '2011-12-21',
#                '2011-12-22', '2011-12-23', '2011-12-27', '2011-12-28',
#                '2011-12-29', '2011-12-30'],
#               dtype='datetime64[ns]', name='Date', length=1323, freq=None)

# %%
aapl.columns
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
ts = aapl['Close'][-10:] #Últimas 10 observações da coluna 'Close'
print(type(ts))
ts = aapl[['Close']]
print(type(ts))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
# loc - baseado em label
# iloc - baseado em posição

# Mostra as primeiras linhas de Novembro a Dezembro de 2006
print(aapl.loc[pd.Timestamp('2006-11-01'):pd.Timestamp('2006-12-31')].head())
print('----------------------------------------------------------------------------')

# Mostra as primeiras linhas de 2007
print(aapl.loc['2007'].head())
print('----------------------------------------------------------------------------')

# Mostra Novembro de 2006
print(aapl.iloc[22:43])
print('----------------------------------------------------------------------------')

# Mostra os valores de 'Open' e 'Close' de 2006-11-01 a 2006-12-01
print(aapl.iloc[[22, 43], [0, 3]])
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2006-11-01  11.625714  11.194285  11.585714  11.308572  152798100   9.772183
# 2006-11-02  11.331429  11.214286  11.274285  11.282857  116370800   9.749961
# 2006-11-03  11.361428  11.112857  11.337143  11.184286  107972200   9.664781
# 2006-11-06  11.437143  11.204286  11.278571  11.387143  108644200   9.840077
# 2006-11-07  11.571428  11.447143  11.492857  11.501429  131483100   9.938838
# ----------------------------------------------------------------------------
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2007-01-03  12.368571  11.700000  12.327143  11.971429  309579900  10.344985
# 2007-01-04  12.278571  11.974286  12.007143  12.237143  211815100  10.574598
# 2007-01-05  12.314285  12.057143  12.252857  12.150000  208685400  10.499294
# 2007-01-08  12.361428  12.182858  12.280000  12.210000  199276700  10.551140
# 2007-01-09  13.282857  12.164286  12.350000  13.224286  837324600  11.427628
# ----------------------------------------------------------------------------
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2006-11-01  11.625714  11.194285  11.585714  11.308572  152798100   9.772183
# 2006-11-02  11.331429  11.214286  11.274285  11.282857  116370800   9.749961
# 2006-11-03  11.361428  11.112857  11.337143  11.184286  107972200   9.664781
# 2006-11-06  11.437143  11.204286  11.278571  11.387143  108644200   9.840077
# 2006-11-07  11.571428  11.447143  11.492857  11.501429  131483100   9.938838
# 2006-11-08  11.812857  11.412857  11.431429  11.778571  172729200  10.178325
# 2006-11-09  12.098572  11.731428  11.842857  11.905714  230763400  10.288195
# 2006-11-10  11.942857  11.785714  11.935715  11.874286   93466100  10.261038
# 2006-11-13  12.064285  11.805715  11.888572  12.050000  112668500  10.412880
# 2006-11-14  12.142858  11.985714  12.114285  12.142858  147238700  10.493119
# 2006-11-15  12.271428  12.000000  12.150000  12.007143  163830800  10.375845
# 2006-11-16  12.328571  12.088572  12.124286  12.230000  173485200  10.568424
# 2006-11-17  12.277143  12.142858  12.162857  12.264286  116606000  10.598052
# 2006-11-20  12.428572  12.171429  12.200000  12.352858  142698500  10.674593
# 2006-11-21  12.657143  12.444285  12.488571  12.657143  155666700  10.937533
# 2006-11-22  12.964286  12.550000  12.712857  12.901428  167985300  11.148633
# 2006-11-24  13.297143  12.785714  12.790000  13.090000  129669400  11.311584
# 2006-11-27  13.308572  12.785714  13.215714  12.791429  268709000  11.053575
# 2006-11-28  13.138572  12.844286  12.908571  13.115714  259043400  11.333805
# 2006-11-29  13.307143  12.892858  13.285714  13.114285  289270800  11.332567
# 2006-11-30  13.240000  13.008572  13.172857  13.094286  217621600  11.315289
# ----------------------------------------------------------------------------
#                  High      Close
# Date
# 2006-11-01  11.625714  11.308572
# 2006-12-01  13.190000  13.045714

# %%
# Amostra 20 linhas
print(aapl.sample(20))
print('----------------------------------------------------------------------------')

# Reamostra os dados para meses por média dos valores
print(aapl.resample('M').mean())
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2008-04-17  22.285715  21.907143  22.024286  22.070000  176066800  19.071554
# 2011-08-24  54.137142  52.942856  53.352856  53.740002  156566900  46.438843
# 2007-09-28  22.085714  21.821428  21.920000  21.924286  153775300  18.945639
# 2011-06-13  46.901428  46.438572  46.742859  46.657143   82368300  40.318272
# 2007-01-16  13.892858  13.635715  13.668571  13.871428  311019100  11.986848
# 2011-06-24  47.592857  46.441429  47.338570  46.621429  109951800  40.287411
# 2009-06-04  20.597143  20.005714  20.018572  20.534286  137658500  17.744484
# 2009-02-23  13.142858  12.358571  13.092857  12.421429  196745500  10.733847
# 2007-11-19  24.028572  23.157143  23.728571  23.421429  288607200  20.239376
# 2007-06-07  18.230000  17.598572  17.855715  17.724285  478769900  15.316252
# 2006-11-07  11.571428  11.447143  11.492857  11.501429  131483100   9.938838
# 2007-11-06  27.428572  26.467142  26.721428  27.398571  238681800  23.676182
# 2007-04-19  13.035714  12.832857  12.884286  12.895715  106478400  11.143695
# 2008-11-13  13.777143  12.288571  12.838572  13.777143  463521800  11.905371
# 2007-03-01  12.615714  11.964286  12.004286  12.437143  353882200  10.747427
# 2011-06-22  46.985714  46.054287  46.451427  46.087143   97645800  39.825710
# 2011-07-11  51.395714  50.402859  50.905716  50.571430  110668600  43.700775
# 2009-12-09  28.308571  27.187143  27.325714  28.257143  171195500  24.418110
# 2007-06-14  17.064285  16.631428  16.742857  16.964285  243316500  14.659503
# 2008-06-20  25.857143  25.000000  25.621429  25.038572  222091800  21.636816
# ----------------------------------------------------------------------------
#                  High        Low       Open      Close        Volume  \
# Date
# 2006-10-31  11.123766  10.893117  11.002922  11.017987  1.634995e+08
# 2006-11-30  12.314626  12.028980  12.161565  12.192109  1.647010e+08
# 2006-12-31  12.546500  12.205571  12.415857  12.353071  2.111349e+08
# 2007-01-31  12.880857  12.522572  12.722357  12.697357  3.401223e+08
# 2007-02-28  12.382932  12.111804  12.252105  12.246842  1.805573e+08
# ...               ...        ...        ...        ...           ...
# 2011-08-31  54.550000  53.021304  53.894347  53.823230  1.754630e+08
# 2011-09-30  56.745918  55.438096  56.054217  56.070476  1.425887e+08
# 2011-10-31  57.402380  55.932245  56.677687  56.747143  1.564456e+08
# 2011-11-30  55.554218  54.526599  55.181157  54.973606  1.067107e+08
# 2011-12-31  56.523537  55.734217  56.110068  56.132925  7.507777e+07
#
#             Adj Close
# Date
# 2006-10-31   9.521076
# 2006-11-30  10.535681
# 2006-12-31  10.674776
# 2007-01-31  10.972286
# 2007-02-28  10.582978
# ...               ...
# 2011-08-31  46.510771
# 2011-09-30  48.452706
# 2011-10-31  49.037439
# 2011-11-30  47.504853
# 2011-12-31  48.506672
#
# [63 rows x 6 columns]

# %%
# Adiciona uma coluna 'diff' que é a diferença entre 'Open' e 'Close'
aapl['diff'] = aapl.Open - aapl.Close # Outra opção é aapl['diff'] = aapl['Open'] - aapl['Close']
print(aapl.head())
print('----------------------------------------------------------------------------')

# Remove a coluna 'diff'
del aapl['diff'] # Outra opção é aapl = aapl.drop(columns=['diff'])
print(aapl.head())
# Out:
#                  High        Low       Open      Close     Volume  Adj Close  \
# Date
# 2006-10-02  10.838572  10.614285  10.728572  10.694285  178159800   9.241351
# 2006-10-03  10.707143  10.455714  10.635715  10.582857  197677200   9.145061
# 2006-10-04  10.780000  10.451428  10.585714  10.768572  207270700   9.305547
# 2006-10-05  10.880000  10.590000  10.647142  10.690000  170970800   9.237648
# 2006-10-06  10.720000  10.544286  10.631429  10.602858  116739700   9.162347
#
#                 diff
# Date
# 2006-10-02  0.034286
# 2006-10-03  0.052857
# 2006-10-04 -0.182858
# 2006-10-05 -0.042857
# 2006-10-06  0.028571
# ----------------------------------------------------------------------------
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2006-10-02  10.838572  10.614285  10.728572  10.694285  178159800   9.241351
# 2006-10-03  10.707143  10.455714  10.635715  10.582857  197677200   9.145061
# 2006-10-04  10.780000  10.451428  10.585714  10.768572  207270700   9.305547
# 2006-10-05  10.880000  10.590000  10.647142  10.690000  170970800   9.237648
# 2006-10-06  10.720000  10.544286  10.631429  10.602858  116739700   9.162347

# %%
# Cria uma figura para o plot. figsize=(Largura,Altura)
plt.figure(figsize=(12, 8))

# Plota a coluna 'Close'
aapl['Close'].plot(grid=True)

plt.figure(figsize=(12, 8))
# Plota a coluna 'Open'
plt.plot(aapl.index, aapl['Open'], ':', color='red')

# Mostra o plot
plt.show()

# %%
# Coloca em 'daily_close' a coluna 'Adj Close' (em DataFrame)
daily_close = aapl[['Adj Close']]

# Calcula a mudança percentual diária - representa a quantidade de variação
# percentual no valor de uma ação em um único dia de negociação
daily_pct_change = daily_close.pct_change()

# Substitui os locais sem valor (NA) por 0
daily_pct_change.fillna(0, inplace=True)
print(daily_pct_change)
print('-----------------------')

# Log dos retornos diarios - calcula o log para observar melhor o crescimento 
# de seus retornos ao longo do tempo
daily_log_returns = np.log(daily_pct_change+1)
print(daily_log_returns)
# Out:
#             Adj Close
# Date
# 2006-10-02   0.000000
# 2006-10-03  -0.010419
# 2006-10-04   0.017549
# 2006-10-05  -0.007297
# 2006-10-06  -0.008152
# ...               ...
# 2011-12-23   0.011993
# 2011-12-27   0.007934
# 2011-12-28  -0.009569
# 2011-12-29   0.006160
# 2011-12-30  -0.000296
#
# [1323 rows x 1 columns]
# -----------------------
#             Adj Close
# Date
# 2006-10-02   0.000000
# 2006-10-03  -0.010474
# 2006-10-04   0.017397
# 2006-10-05  -0.007323
# 2006-10-06  -0.008185
# ...               ...
# 2011-12-23   0.011922
# 2011-12-27   0.007903
# 2011-12-28  -0.009615
# 2011-12-29   0.006141
# 2011-12-30  -0.000296
#
# [1323 rows x 1 columns]

# %%
# Reamostra para meses comerciais pegando a última observação
monthly = aapl.resample('BM').apply(lambda x: x[-1])
print(monthly.pct_change())
print('-----------------------------------------------------------------------')

# Reamostra para trimestres pegando a média do trimestre
quarter = aapl.resample("4M").mean()
print(quarter.pct_change())
# Out:
#                 High       Low      Open     Close    Volume  Adj Close
# Date
# 2006-10-31       NaN       NaN       NaN       NaN       NaN        NaN
# 2006-11-30  0.134672  0.134987  0.132106  0.130488  0.735854   0.130489
# 2006-12-29 -0.078550 -0.084560 -0.089578 -0.074405  0.236584  -0.074405
# 2007-01-31  0.007026  0.011876  0.010840  0.010490 -0.204714   0.010490
# 2007-02-28 -0.004651 -0.016005 -0.021918 -0.013064  0.074066  -0.013064
# ...              ...       ...       ...       ...       ...        ...
# 2011-08-31 -0.007769 -0.005573  0.007559 -0.014469 -0.173887  -0.014469
# 2011-09-30 -0.008136 -0.001781 -0.008833 -0.009121  0.047943  -0.009121
# 2011-10-31  0.052560  0.052128  0.039523  0.061523 -0.296069   0.061523
# 2011-11-30 -0.066084 -0.056726 -0.052507 -0.055783  0.053015  -0.055783
# 2011-12-30  0.062781  0.066587  0.058276  0.059655 -0.557416   0.059655
#
# [63 rows x 6 columns]
# -----------------------------------------------------------------------
#                 High       Low      Open     Close    Volume  Adj Close
# Date
# 2006-10-31       NaN       NaN       NaN       NaN       NaN        NaN
# 2007-02-28  0.126451  0.121460  0.125777  0.122860  0.369611   0.122860
# 2007-06-30  0.195413  0.198331  0.196030  0.197735 -0.080296   0.197735
# 2007-10-31  0.404613  0.392010  0.400961  0.400796  0.306882   0.400796
# 2008-02-29  0.130711  0.117746  0.127066  0.120394  0.172293   0.120394
# 2008-06-30 -0.004290  0.005927 -0.003550  0.003673 -0.209762   0.003673
# 2008-10-31 -0.108879 -0.124618 -0.114267 -0.118803  0.133219  -0.118803
# 2009-02-28 -0.363388 -0.359305 -0.363639 -0.360865 -0.161601  -0.360865
# 2009-06-30  0.304359  0.324702  0.312134  0.316588 -0.386935   0.316588
# 2009-10-31  0.411193  0.425117  0.421239  0.415901 -0.158270   0.415901
# 2010-02-28  0.176085  0.172864  0.175612  0.173693  0.170633   0.173693
# 2010-06-30  0.223317  0.219063  0.223045  0.223611  0.203680   0.223611
# 2010-10-31  0.094268  0.099356  0.094380  0.096125 -0.157478   0.096125
# 2011-02-28  0.218082  0.225622  0.221393  0.221858 -0.230726   0.221858
# 2011-06-30  0.033863  0.031616  0.034143  0.031222 -0.043455   0.031222
# 2011-10-31  0.133189  0.124572  0.127202  0.130452  0.429821   0.130452
# 2012-02-29  0.008387  0.016799  0.013755  0.011002 -0.404723   0.011002

# %%
# Plot o histograma de 'daily_pct_change'
hist = daily_pct_change.hist(bins=50, figsize=(12, 8))
plt.show()

# Mostra o resumo de estatisticas
print(daily_pct_change.describe())
# Out:
#          Adj Close
# count  1323.000000
# mean      0.001565
# std       0.023983
# min      -0.179195
# 25%      -0.010661
# 50%       0.001646
# 75%       0.014285
# max       0.139049

# %%
# Calcula a taxa de retorno cumulativa diária
cum_daily_return = (1 + daily_pct_change).cumprod()
cum_daily_return.plot(figsize=(12, 8))
plt.show()

# %%
# Reamostra a taxa de retorno cumulativa diária para taxa de retorno cumulativa mensal
cum_monthly_return = cum_daily_return.resample("M").mean()
cum_monthly_return.plot(figsize=(12, 8))
plt.show()

# %% [markdown]
# ## Trabalhando com dados da Apple, Microsoft, IBM e Google

# %%
def get_data(tickers_list, start_date, end_date):
    def data(ticker):
        return (pdr.get_data_yahoo(ticker, start=start_date, end=end_date))
    datas = map(data, tickers_list)
    return(pd.concat(datas, keys=tickers_list, names=['Ticker', 'Date']))

# %%
tickers_list = ['AAPL', 'MSFT', 'IBM', 'GOOG']
all_data = get_data(tickers_list, datetime.datetime(2006, 10, 1), datetime.datetime(2012, 1, 1))
all_data
# Out:
#                          High         Low        Open       Close  \
# Ticker Date
# AAPL   2006-10-02   10.838572   10.614285   10.728572   10.694285
#        2006-10-03   10.707143   10.455714   10.635715   10.582857
#        2006-10-04   10.780000   10.451428   10.585714   10.768572
#        2006-10-05   10.880000   10.590000   10.647142   10.690000
#        2006-10-06   10.720000   10.544286   10.631429   10.602858
# ...                       ...         ...         ...         ...
# GOOG   2011-12-23  316.154968  314.102661  314.819977  315.387848
#        2011-12-27  321.041656  314.819977  314.844879  318.929565
#        2011-12-28  321.295715  317.858582  320.174896  318.655609
#        2011-12-29  320.299438  316.414001  319.547272  320.000549
#        2011-12-30  322.172424  319.811279  319.811279  321.744019
#
#                         Volume   Adj Close
# Ticker Date
# AAPL   2006-10-02  178159800.0    9.241351
#        2006-10-03  197677200.0    9.145061
#        2006-10-04  207270700.0    9.305547
#        2006-10-05  170970800.0    9.237648
#        2006-10-06  116739700.0    9.162347
# ...                        ...         ...
# GOOG   2011-12-23    2918200.0  315.387848
#        2011-12-27    3224800.0  318.929565
#        2011-12-28    4270200.0  318.655609
#        2011-12-29    3162500.0  320.000549
#        2011-12-30    3577800.0  321.744019
#
# [5292 rows x 6 columns]

# %%
# Altera o DataFrame de forma que o índice seja 'Date', as colunas 'Ticker' e os valores 'Adj Close'
daily_close_px = all_data[['Adj Close']].reset_index().pivot('Date', 'Ticker', 'Adj Close')

# Calcula a mudança percentual diária para 'daily_close_px'
daily_pct_change = daily_close_px.pct_change()

# Plota os histogramas
daily_pct_change.hist(bins=50, sharex=True, figsize=(12, 8))
plt.show()

# %%
# Plota uma matriz de dispersão de 'daily_pct_change'
pd.plotting.scatter_matrix(daily_pct_change, diagonal='kde', alpha=0.1,figsize=(12, 12))
plt.show()

# %% [markdown]
# ## Janela Móvel

# %%
# Isolando o preço de fechamento ajustado
adj_close_px = aapl['Adj Close']

# Calcula a média móvel
moving_avg = adj_close_px.rolling(window=40).mean()

# Calcula o máximo móvel
moving_max = adj_close_px.rolling(window=40).max()

plt.figure(figsize=(12, 8))
adj_close_px.plot(label='Real')
moving_max.plot(color='green', label='Máximo Móvel')
moving_avg.plot(color='red', label='Média Móvel')
plt.legend(fontsize=12)
plt.show()

# %%
# Janela de tamanho 42
aapl['42'] = adj_close_px.rolling(window=40).mean()

# Janela de tamanho 252
aapl['252'] = adj_close_px.rolling(window=252).mean()

aapl[['Adj Close', '42', '252']].plot(figsize=(12, 8))
plt.show()

# %% [markdown]
# ## Volatilidade

# %%
# Define o tamanho da janela da avaliação
min_periods = 75 

# Calcula a volatilidade
vol = daily_pct_change.rolling(min_periods).std() * np.sqrt(min_periods) 

vol.plot(figsize=(12, 8))
plt.show()

# %% [markdown]
# ## Regressão de Mínimos Quadrados

# %%
# Isolando o preço de fechamento ajustado
all_adj_close = all_data[['Adj Close']]

# Calcula os ganhos
all_returns = np.log(all_adj_close / all_adj_close.shift(1))

# Isola os valores da AAPL
aapl_returns = all_returns.iloc[all_returns.index.get_level_values('Ticker') == 'AAPL']
aapl_returns.index = aapl_returns.index.droplevel('Ticker')

# Isola os valores da MSFT
msft_returns = all_returns.iloc[all_returns.index.get_level_values('Ticker') == 'MSFT']
msft_returns.index = msft_returns.index.droplevel('Ticker')

# Constroi um novo DataFrame com os ganhos da AAPL e MSFT
return_data = pd.concat([aapl_returns, msft_returns], axis=1)[1:]
return_data.columns = ['AAPL', 'MSFT']

# Adiciona uma constante (eixo x para o modelo)
X = sm.add_constant(return_data['AAPL'])

# Constroi o modelo (procura modelar a relação entre ganhos da AAPL e da MSFT)
model = sm.OLS(return_data['MSFT'],X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   MSFT   R-squared:                       0.281
# Model:                            OLS   Adj. R-squared:                  0.280
# Method:                 Least Squares   F-statistic:                     515.5
# Date:                Thu, 13 Aug 2020   Prob (F-statistic):           1.33e-96
# Time:                        14:52:42   Log-Likelihood:                 3514.0
# No. Observations:                1322   AIC:                            -7024.
# Df Residuals:                    1320   BIC:                            -7014.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0005      0.000     -1.119      0.263      -0.001       0.000
# AAPL           0.4407      0.019     22.704      0.000       0.403       0.479
# ==============================================================================
# Omnibus:                      268.592   Durbin-Watson:                   2.074
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7029.415
# Skew:                          -0.211   Prob(JB):                         0.00
# Kurtosis:                      14.289   Cond. No.                         41.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
plt.figure(figsize=(12, 8))

# Plota os ganhos da AAPÇ e MSFT
plt.plot(return_data['AAPL'], return_data['MSFT'], 'r.')

# Adiciona um eixo ao plot
ax = plt.axis()

# Cria um vetor x para mostrar o modelo
x = np.linspace(ax[0], ax[1] + 0.01)

# Plota a linha de regressão
plt.plot(x, model.params[0] + model.params[1] * x, 'b', lw=2)

plt.grid(True) # Adiciona o grid
plt.axis('tight') # Reduz os espaços em branco
plt.xlabel('Apple Returns') # Nomeia o eixo x
plt.ylabel('Microsoft returns') # Nomeia o eixo y
plt.show()

# %%
# Plota a correlação móvel entre ganhos da AAPL e da MSFT
return_data['MSFT'].rolling(window=252).corr(return_data['AAPL']).plot(figsize=(12, 8))
plt.show()

# %% [markdown]
# ## Estratégia de Negociação

# %%
# Define os tamanhos das janelas
short_window = 40
long_window = 100

# Cria o DataFrame 'signals' com o index da AAPL e com a coluna 'signal' inicializada com 0.0
signals = pd.DataFrame(index=aapl.index)
signals['signal'] = 0.0

# Cria a janela curta
signals['short_mavg'] = aapl['Close'].rolling(window=short_window, min_periods=1, center=False).mean()

# Cria a janela longa
signals['long_mavg'] = aapl['Close'].rolling(window=long_window, min_periods=1, center=False).mean()

# Preenche a coluna 'signal' com a indicação de quando 'short_mavg'>'long_mavg'
signals['signal'][short_window:] = np.where(signals['short_mavg'][short_window:]>signals['long_mavg'][short_window:], 1.0, 0.0)   

# Faz a diferença do sinal atual com o anterior para criar a ordem
#  1 - Compra
#  0 - Não faz nada
# -1 - Vende
signals['positions'] = signals['signal'].diff()
print(signals)
# Out:
#             signal  short_mavg  long_mavg  positions
# Date
# 2006-10-02     0.0   10.694285  10.694285        NaN
# 2006-10-03     0.0   10.638571  10.638571        0.0
# 2006-10-04     0.0   10.681905  10.681905        0.0
# 2006-10-05     0.0   10.683928  10.683928        0.0
# 2006-10-06     0.0   10.667714  10.667714        0.0
# ...            ...         ...        ...        ...
# 2011-12-23     1.0   55.439643  55.406957        0.0
# 2011-12-27     0.0   55.445286  55.448614       -1.0
# 2011-12-28     0.0   55.437643  55.490072        0.0
# 2011-12-29     0.0   55.468393  55.564229        0.0
# 2011-12-30     0.0   55.495500  55.608500        0.0
#
# [1323 rows x 4 columns]

# %%
fig = plt.figure(figsize=(12, 8))
ax1 = fig.add_subplot(111,  ylabel='Price in $')

# Plota o preço de fechamento em vermelho
aapl['Close'].plot(ax=ax1, color='r', lw=2.)

# Plota os sinais das janelas
signals[['short_mavg', 'long_mavg']].plot(ax=ax1, lw=2.)

# Plota o sinal de compra (triangulo magenta)
ax1.plot(signals.loc[signals.positions == 1.0].index, 
         signals.short_mavg[signals.positions == 1.0],
         '^', markersize=10, color='m')
         
# Plota o sinal de venda (triangulo inverido preto)
ax1.plot(signals.loc[signals.positions == -1.0].index, 
         signals.short_mavg[signals.positions == -1.0],
         'v', markersize=10, color='k')
plt.show()

# %%
# Define o capital inicial
initial_capital= float(100000.0)

# Cria o DataFrame 'positions'
positions = pd.DataFrame(index=signals.index).fillna(0.0)

# Compra 100 ações
positions['AAPL'] = 100*signals['signal']   
  
# Inicializa o portifolio com o valor possuído
portfolio = positions.multiply(aapl['Adj Close'], axis=0)

# Armazena a diferença em ações possuídas
pos_diff = positions.diff()

# Adiciona 'holdings' ao portifolio
portfolio['holdings'] = (positions.multiply(aapl['Adj Close'], axis=0)).sum(axis=1)

# Adiciona 'cash' ao portifolio
portfolio['cash'] = initial_capital - (pos_diff.multiply(aapl['Adj Close'], axis=0)).sum(axis=1).cumsum()   

# Adiciona 'total' ao portifolio
portfolio['total'] = portfolio['cash'] + portfolio['holdings']

# Adiciona 'returns' ao portifolio
portfolio['returns'] = portfolio['total'].pct_change()
print(portfolio.head())
# Out:
#             AAPL  holdings      cash     total  returns
# Date
# 2006-10-02   0.0       0.0  100000.0  100000.0      NaN
# 2006-10-03   0.0       0.0  100000.0  100000.0      0.0
# 2006-10-04   0.0       0.0  100000.0  100000.0      0.0
# 2006-10-05   0.0       0.0  100000.0  100000.0      0.0
# 2006-10-06   0.0       0.0  100000.0  100000.0      0.0

# %%
fig = plt.figure(figsize=(12, 8))
ax1 = fig.add_subplot(111, ylabel='Portfolio value in $')

# Plota o portifolio total em dolares
portfolio['total'].plot(ax=ax1, lw=2.)

# Plota o sinal de compra (triangulo magenta)
ax1.plot(portfolio.loc[signals.positions == 1.0].index, 
         portfolio.total[signals.positions == 1.0],
         '^', markersize=10, color='m')

# Plota o sinal de compra (triangulo invertido preto)
ax1.plot(portfolio.loc[signals.positions == -1.0].index, 
         portfolio.total[signals.positions == -1.0],
         'v', markersize=10, color='k')
plt.show()

# %% [markdown]
# ## Sharpe ratio
#
# - Mostra se o retorno obtido é resultado de boas decisões de investimento ou de tomar grandes riscos
# - Usualmente para investidores um valor maior que:
#     - 1 é aceitável
#     - 2 é muito bom
#     - 3 é excelente

# %%
# Isola os retornos da estrategia
returns = portfolio['returns']

# Calcula o Sharpe ratio anual - 252 dias úteis no ano
sharpe_ratio = np.sqrt(252) * (returns.mean() / returns.std())
print('Sharpe ratio: {}'.format(sharpe_ratio))
# Out:
# Sharpe ratio: 0.7258718138402565

# %% [markdown]
# ## Maximum Drawdown
#
# - Mede a maior queda do pico ao fundo no valor de um portfólio
# - Indica o risco do portifolio dada a estrategia

# %%
# Define uma janela de tamanho 252 - 252 dias úteis no ano
window = 252

# Calcula o maximum drawdown na janela para cada dia
rolling_max = aapl['Adj Close'].rolling(window, min_periods=1).max()
daily_drawdown = aapl['Adj Close']/rolling_max - 1.0

# Calcula o mínimo drawdown diario
max_daily_drawdown = daily_drawdown.rolling(window, min_periods=1).min()

# Plota os resultados
fig = plt.figure(figsize=(12, 8))
daily_drawdown.plot()
max_daily_drawdown.plot()
plt.show()

# %% [markdown]
# ## Compound Annual Growth Rate (CAGR)
#
# - Taxa constante de retorno por um periodo de tempo
# - Mostra o que você realmente obteve ao final do sei periodo de investimento
# - $EV$ - valor ao final do investimento
# - $BV$ - valor inicial do investimento
# - $n$ - tamanho do periodo
# - $CAGR = (EV/BV)^{1/n}-1$

# %%
# Pega o número de dias em AAPL
days = (aapl.index[-1] - aapl.index[0]).days

# Calcula o CAGR 
cagr = ((((aapl['Adj Close'][-1]) / aapl['Adj Close'][1])) ** (365.0/days)) - 1
print('CAGR: {}'.format(cagr))
# Out:
# CAGR: 0.3823446182157444
